# %% [markdown]
# # AIsteroid
# [http://bit.ly/aisteroid](http://bit.ly/aisteroid)

# %%
from aisteroid import *
# %matplotlib nbagg

# %% [markdown]
# ## Task: Perform astrometry of images

# %% [markdown]
# ### Choose the image set

# %%
if QIPY:
    #listImages() ##See the list of imagesets
    #CONF.SET="example" ##Choose your preferred imageset
    #CONF.CFG="example" ##You choose your preferred observatory configuration (example.cfg)
    CONF.OVERWRITE=1 ##Overwrite all previous actions
    CONF.VERBOSE=1 ## Show all outputs

# %% [markdown]
# #### DO NOT TOUCH IF YOU ARE NOT SURE

# %%
#DO NOT MODIFY THIS LINES
print0("*"*60+"\nASTROMETRY OF IMAGE SET'%s'\n"%CONF.SET+"*"*60)
OUT_DIR=CONF.SCR_DIR+CONF.SET+"/"
CFG=[line.rstrip('\n') for line in open(CONF.SETS_DIR+CONF.CFG+".cfg")]
AIA=dict()
AIA_FILE=OUT_DIR+CONF.SET+".aia"
SET_FILE=CONF.SETS_DIR+CONF.SET+".zip"
PLOT_DIR=OUT_DIR+"plots/"
FLOG=open(OUT_DIR+"astrometry.log","a")
SYSOPTS=dict(qexit=[True,FLOG])
if not os.path.isfile(AIA_FILE):
    error("Set '%s' has not been unpacked"%CONF.SET)
else:
    System("cp "+CONF.INPUT_DIR+"analysis/* "+OUT_DIR)
    AIA=pickle.load(open(AIA_FILE,"rb"))
    images=AIA["images"]
    sources=AIA["sources"]
    borders=AIA["borders"]
    nimgs=len(images)
# Out:
# ************************************************************
# ASTROMETRY OF IMAGE SET'example'
# ************************************************************

# %% [markdown]
# ### Telescope and camera (detector) properties

# %%
print0("Telescope & CCD Properties:")
if not "detector" in AIA.keys() or CONF.OVERWRITE:
    #Telescope and camera (detector) properties
    detector=dictObj(dict())
    detector.FOCAL=Config(CFG,"FocalLength") #mm
    detector.PW=Config(CFG,"PixelWide") #mm
    detector.PH=Config(CFG,"PixelHigh") #mm
    detector.SIZEX=images[0]["header"]["NAXIS1"]
    detector.SIZEY=images[0]["header"]["NAXIS2"]
    detector.PWD=np.arctan(detector.PW/detector.FOCAL)*RAD
    detector.PHD=np.arctan(detector.PW/detector.FOCAL)*RAD
    detector.PXSIZE=(detector.PWD+detector.PHD)/2
    
    
    AIA["detector"]=detector
    pickle.dump(AIA,open(AIA_FILE,"wb"))
else:
    print("\tDetector properties already extracted")
    AIA=pickle.load(open(AIA_FILE,"rb"))
    detector=AIA["detector"]

print0("\tFocal lenght (mm) :",detector.FOCAL)
print0("\tPixel size (x mm,y mm) :",detector.PW,detector.PH)
print0("\tImage size (x px,y px) :",detector.SIZEX,detector.SIZEY)
print0("\tPixel size (arcsec):",detector.PXSIZE/ARCSEC)
print0("\tCamera field (x deg,y deg) :",detector.SIZEX*detector.PWD,detector.SIZEY*detector.PHD)
print("\tDone.")
# Out:
# Telescope & CCD Properties:
# 	Focal lenght (mm) : 8070.0
# 	Pixel size (x mm,y mm) : 0.01 0.01
# 	Image size (x px,y px) : 2423 2434
# 	Pixel size (arcsec): 0.255594555449
# 	Camera field (x deg,y deg) : 0.172029335514 0.172810318878
# 	Done.

# %% [markdown]
# ### Astrometry using astromery.net

# %%
x="X_IMAGE"
y="Y_IMAGE"
cs=[x,y]

for i,image in enumerate(images):

    file=image["file"]
    header=image["header"]

    # Get bright stars
    imgsources=sources[sources.IMG==i]
    border=borders[i]    
    
    #Choose the first NREFSTARS far from defects
    nbright=0
    indbright=[]
    for ind in imgsources.index:
        dmin=(np.sqrt((imgsources.loc[ind,x]-border[:,0])**2+\
                      (imgsources.loc[ind,y]-border[:,1])**2)).min()
        if dmin<2*CONF.RADIUS:continue
        indbright+=[ind]
        nbright+=1
        if nbright>=CONF.NREFSTARS:break

    bright=imgsources.loc[indbright]
    sources.loc[indbright,"STAR"]=1
    nbright=len(bright)

    print("\t\tNumber of selected bright stars:",len(bright))
    
    # Read fits and replace with bright stars
    img=OUT_DIR+file+".fits"
    hdul=fits.open(img)
    data=hdul[0].data
    data=np.zeros_like(data)
    for ind in bright.index:
        data[int(bright.loc[ind,"X_IMAGE"]),int(bright.loc[ind,"Y_IMAGE"])]=255
    hdul[0].data=data
    hdul.writeto(OUT_DIR+"this-%d.fits"%i,overwrite=True)
    hdul.close()
    
    #GET COORDINATES
    ra=sex2dec(header["OBJCTRA"])*15
    dec=sex2dec(header["OBJCTDEC"])

    #ASTROMETRY.NET COMMAND
    print("Running astrometry over %s..."%file)
    opts=""
    opts+=" "+"--use-sextractor --sextractor-path "+CONF.SEX_DIR+"bin/sex"
    opts+=" "+"--no-plots"
    opts+=" "+"--ra %.7f --dec %.7f --radius 1"%(ra,dec)
    opts+=" "+"--guess-scale --overwrite"
    cmd=CONF.AST_DIR+"bin/solve-field "+opts+" "+"this-%d.fits"%i
    sys="cd "+OUT_DIR+";"+cmd
    out=System(sys,True)
    
    print("\tAstrometry processing successful")
    #break
    
print("Done.")
# Out:
# 		Number of selected bright stars: 20
# Running astrometry over o8009g0075o.1299949.ch.1991737.XY51.p10...
# Reading input file 1 of 1: "this-0.fits"...
# Found an existing WCS header, will try to verify it.
# Extracting sources...
# Sorting brightness using MAG_AUTO and BACKGROUND columns failed; falling back to MAG_AUTO.
# Reading sort column "MAG_AUTO"
# Sorting sort column
# mmapping input file
# Copying table header.
# Writing row 0
# Done
# Solving...
# Warning: encountered two index files with the same INDEXID = 4107 and HEALPIX = -1: "/home/astrometry/astrometry/data/index-4107.fits.1" and "/home/astrometry/astrometry/data/index-4107.fits".  Keeping both.
# Reading file "./this-0.axy"...
# Only searching for solutions within 1 degrees of RA,Dec (315.546,-15.5833)
# Verifying WCS using indices with quads of size [1.03379, 10.3848] arcmin
# Verifying WCS with index 2 of 4 (/home/astrometry/astrometry/data/index-4204-47.fits)
# Verifying WCS of field 1.
#  --> log-odds 0
# Verifying WCS with index 3 of 4 (/home/astrometry/astrometry/data/index-4203-47.fits)
# Verifying WCS of field 1.
#  --> log-odds 0
# Verifying WCS with index 4 of 4 (/home/astrometry/astrometry/data/index-4202-47.fits)
# Verifying WCS of field 1.
#  --> log-odds 0
# Got 0 solutions.
# Field 1 did not solve (index index-4205-11.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-47.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-47.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-47.fits, field objects 1-10).
# Field 1 did not solve (index index-4205-11.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-47.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-47.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-47.fits, field objects 1-10).
# Field 1 did not solve (index index-4205-11.fits, field objects 11-20).
#   log-odds ratio 65.9341 (4.31315e+28), 10 match, 0 conflict, 6 distractors, 19 index.
#   RA,Dec = (316.04,-15.5827), pixel scale 0.255243 arcsec/pix.
#   Hit/miss:   Hit/miss: +-+----+++++++-+(best)++++
# Field 1: solved with index index-4204-47.fits.
# Field 1 solved: writing to file ./this-0.solved to indicate this.
# Field: this-0.fits
# Field center: (RA,Dec) = (316.040202, -15.582472) deg.
# Field center: (RA H:M:S, Dec D:M:S) = (21:04:09.649, -15:34:56.901).
# Field size: 10.3167 x 10.3917 arcminutes
# Field rotation angle: up is 14.6524 degrees E of N
# Field parity: pos
# Creating new FITS file "./this-0.new"...
# 	Astrometry processing successful
# 		Number of selected bright stars: 20
# Running astrometry over o8009g0096o.1299970.ch.1991758.XY51.p10...
# Reading input file 1 of 1: "this-1.fits"...
# Found an existing WCS header, will try to verify it.
# Extracting sources...
# Sorting brightness using MAG_AUTO and BACKGROUND columns failed; falling back to MAG_AUTO.
# Reading sort column "MAG_AUTO"
# Sorting sort column
# mmapping input file
# Copying table header.
# Writing row 0
# Done
# Solving...
# Warning: encountered two index files with the same INDEXID = 4107 and HEALPIX = -1: "/home/astrometry/astrometry/data/index-4107.fits.1" and "/home/astrometry/astrometry/data/index-4107.fits".  Keeping both.
# Reading file "./this-1.axy"...
# Only searching for solutions within 1 degrees of RA,Dec (315.544,-15.5831)
# Verifying WCS using indices with quads of size [1.03382, 10.3851] arcmin
# Verifying WCS with index 2 of 4 (/home/astrometry/astrometry/data/index-4204-47.fits)
# Verifying WCS of field 1.
#  --> log-odds 0
# Verifying WCS with index 3 of 4 (/home/astrometry/astrometry/data/index-4203-47.fits)
# Verifying WCS of field 1.
#  --> log-odds 0
# Verifying WCS with index 4 of 4 (/home/astrometry/astrometry/data/index-4202-47.fits)
# Verifying WCS of field 1.
#  --> log-odds 0
# Got 0 solutions.
# Field 1 did not solve (index index-4205-11.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-47.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-47.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-47.fits, field objects 1-10).
# Field 1 did not solve (index index-4205-11.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-47.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-47.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-47.fits, field objects 1-10).
# Field 1 did not solve (index index-4205-11.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-47.fits, field objects 11-20).
#   log-odds ratio 79.7141 (4.16308e+34), 15 match, 0 conflict, 1 distractors, 37 index.
#   RA,Dec = (316.04,-15.5827), pixel scale 0.255679 arcsec/pix.
#   Hit/miss:   Hit/miss: ++++++++-+++++++(best)++++
# Field 1: solved with index index-4203-47.fits.
# Field 1 solved: writing to file ./this-1.solved to indicate this.
# Field: this-1.fits
# Field center: (RA,Dec) = (316.040113, -15.582289) deg.
# Field center: (RA H:M:S, Dec D:M:S) = (21:04:09.627, -15:34:56.241).
# Field size: 10.3154 x 10.3896 arcminutes
# Field rotation angle: up is 14.6339 degrees E of N
# Field parity: pos
# Creating new FITS file "./this-1.new"...
# 	Astrometry processing successful
# 		Number of selected bright stars: 20
# Running astrometry over o8009g0117o.1299991.ch.1991779.XY51.p10...
# Reading input file 1 of 1: "this-2.fits"...
# Found an existing WCS header, will try to verify it.
# Extracting sources...
# Sorting brightness using MAG_AUTO and BACKGROUND columns failed; falling back to MAG_AUTO.
# Reading sort column "MAG_AUTO"
# Sorting sort column
# mmapping input file
# Copying table header.
# Writing row 0
# Done
# Solving...
# Warning: encountered two index files with the same INDEXID = 4107 and HEALPIX = -1: "/home/astrometry/astrometry/data/index-4107.fits.1" and "/home/astrometry/astrometry/data/index-4107.fits".  Keeping both.
# Reading file "./this-2.axy"...
# Only searching for solutions within 1 degrees of RA,Dec (315.539,-15.5833)
# Verifying WCS using indices with quads of size [1.03376, 10.3846] arcmin
# Verifying WCS with index 2 of 4 (/home/astrometry/astrometry/data/index-4204-47.fits)
# Verifying WCS of field 1.
#  --> log-odds 0
# Verifying WCS with index 3 of 4 (/home/astrometry/astrometry/data/index-4203-47.fits)
# Verifying WCS of field 1.
#  --> log-odds 0
# Verifying WCS with index 4 of 4 (/home/astrometry/astrometry/data/index-4202-47.fits)
# Verifying WCS of field 1.
#  --> log-odds 0
# Got 0 solutions.
# Field 1 did not solve (index index-4205-11.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-47.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-47.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-47.fits, field objects 1-10).
# Field 1 did not solve (index index-4205-11.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-47.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-47.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-47.fits, field objects 1-10).
# Field 1 did not solve (index index-4205-11.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-47.fits, field objects 11-20).
#   log-odds ratio 95.3839 (2.65876e+41), 16 match, 0 conflict, 0 distractors, 37 index.
#   RA,Dec = (316.04,-15.5826), pixel scale 0.255559 arcsec/pix.
#   Hit/miss:   Hit/miss: ++++++++++++++++(best)++++
# Field 1: solved with index index-4203-47.fits.
# Field 1 solved: writing to file ./this-2.solved to indicate this.
# Field: this-2.fits
# Field center: (RA,Dec) = (316.039789, -15.582457) deg.
# Field center: (RA H:M:S, Dec D:M:S) = (21:04:09.549, -15:34:56.845).
# Field size: 10.3176 x 10.3942 arcminutes
# Field rotation angle: up is 14.682 degrees E of N
# Field parity: pos
# Creating new FITS file "./this-2.new"...
# 	Astrometry processing successful
# 		Number of selected bright stars: 20
# Running astrometry over o8009g0138o.1300012.ch.1991800.XY51.p10...
# Reading input file 1 of 1: "this-3.fits"...
# Found an existing WCS header, will try to verify it.
# Extracting sources...
# Sorting brightness using MAG_AUTO and BACKGROUND columns failed; falling back to MAG_AUTO.
# Reading sort column "MAG_AUTO"
# Sorting sort column
# mmapping input file
# Copying table header.
# Writing row 0
# Done
# Solving...
# Warning: encountered two index files with the same INDEXID = 4107 and HEALPIX = -1: "/home/astrometry/astrometry/data/index-4107.fits.1" and "/home/astrometry/astrometry/data/index-4107.fits".  Keeping both.
# Reading file "./this-3.axy"...
# Only searching for solutions within 1 degrees of RA,Dec (315.538,-15.5833)
# Verifying WCS using indices with quads of size [1.03378, 10.3847] arcmin
# Verifying WCS with index 2 of 4 (/home/astrometry/astrometry/data/index-4204-47.fits)
# Verifying WCS of field 1.
#  --> log-odds 0
# Verifying WCS with index 3 of 4 (/home/astrometry/astrometry/data/index-4203-47.fits)
# Verifying WCS of field 1.
#  --> log-odds 0
# Verifying WCS with index 4 of 4 (/home/astrometry/astrometry/data/index-4202-47.fits)
# Verifying WCS of field 1.
#  --> log-odds 0
# Got 0 solutions.
# Field 1 did not solve (index index-4205-11.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-47.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-47.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-47.fits, field objects 1-10).
# Field 1 did not solve (index index-4205-11.fits, field objects 1-10).
# Field 1 did not solve (index index-4204-47.fits, field objects 1-10).
# Field 1 did not solve (index index-4203-47.fits, field objects 1-10).
# Field 1 did not solve (index index-4202-47.fits, field objects 1-10).
# Field 1 did not solve (index index-4205-11.fits, field objects 11-20).
# Field 1 did not solve (index index-4204-47.fits, field objects 11-20).
#   log-odds ratio 95.0048 (1.82004e+41), 16 match, 0 conflict, 0 distractors, 37 index.
#   RA,Dec = (316.04,-15.5827), pixel scale 0.25545 arcsec/pix.
#   Hit/miss:   Hit/miss: ++++++++++++++++(best)++++
# Field 1: solved with index index-4203-47.fits.
# Field 1 solved: writing to file ./this-3.solved to indicate this.
# Field: this-3.fits
# Field center: (RA,Dec) = (316.039785, -15.582531) deg.
# Field center: (RA H:M:S, Dec D:M:S) = (21:04:09.548, -15:34:57.111).
# Field size: 10.3159 x 10.3927 arcminutes
# Field rotation angle: up is 14.6899 degrees E of N
# Field parity: pos
# Creating new FITS file "./this-3.new"...
# 	Astrometry processing successful
# Done.

# %%
print0("Task completed.")
FLOG.close()
# Out:
# Task completed.
